# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianchen98/face_recognition/blob/master/face_recognition_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition

# %%
# !pip install ffmpeg

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

# %%
# Open the input movie file
input_movie = cv2.VideoCapture("/content/bill_gates_video_Trim.mp4")
length = int(input_movie.get(cv2.CAP_PROP_FRAME_COUNT))

# Create an output movie file (make sure resolution/frame rate matches input video!)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_movie = cv2.VideoWriter('output.avi',fourcc, 20.0,(int(input_movie.get(3)),int(input_movie.get(4))))

# %%
#Load some sample pictures and learn how to recognize them.
# !wget https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X.jpg -O bill.jpg
bill_image = face_recognition.load_image_file("bill.jpg")
bill_face_encoding = face_recognition.face_encodings(bill_image)[0]

known_faces = [
    bill_face_encoding
]
# Out:
# --2020-07-19 19:16:48--  https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X.jpg
# Resolving pbs.twimg.com (pbs.twimg.com)... 192.229.237.101, 2600:1480:4000:e5::
# Connecting to pbs.twimg.com (pbs.twimg.com)|192.229.237.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24875 (24K) [image/jpeg]
# Saving to: ‘bill.jpg’
#
# bill.jpg            100%[===================>]  24.29K  --.-KB/s    in 0s
#
# 2020-07-19 19:16:48 (180 MB/s) - ‘bill.jpg’ saved [24875/24875]

# %%
# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
frame_number = 0

while True:
    # Grab a single frame of video
    ret, frame = input_movie.read()
    frame_number += 1

    # Quit when the input video file ends
    if not ret:
        break

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_frame = frame[:, :, ::-1]

    # Find all the faces and face encodings in the current frame of video
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    face_names = []
    for face_encoding in face_encodings:
        # See if the face is a match for the known face(s)
        match = face_recognition.compare_faces(known_faces, face_encoding, tolerance=0.50)

        # If you had more than 2 faces, you could make this logic a lot prettier
        # but I kept it simple for the demo
        name = None
        if match[0]:
            name = "Bill Gates"

        face_names.append(name)

    # Label the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        if not name:
            continue

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 25), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 0.5, (255, 255, 255), 1)

    # Write the resulting image to the output video file
    print("Writing frame {} / {}".format(frame_number, length))
    output_movie.write(frame)
# Out:
# Writing frame 1 / 1482
# Writing frame 2 / 1482
# Writing frame 3 / 1482
# Writing frame 4 / 1482
# Writing frame 5 / 1482
# Writing frame 6 / 1482
# Writing frame 7 / 1482
# Writing frame 8 / 1482
# Writing frame 9 / 1482
# Writing frame 10 / 1482
# Writing frame 11 / 1482
# Writing frame 12 / 1482
# Writing frame 13 / 1482
# Writing frame 14 / 1482
# Writing frame 15 / 1482
# Writing frame 16 / 1482
# Writing frame 17 / 1482
# Writing frame 18 / 1482
# Writing frame 19 / 1482
# Writing frame 20 / 1482
# Writing frame 21 / 1482
# Writing frame 22 / 1482
# Writing frame 23 / 1482
# Writing frame 24 / 1482
# Writing frame 25 / 1482
# Writing frame 26 / 1482
# Writing frame 27 / 1482
# Writing frame 28 / 1482
# Writing frame 29 / 1482
# Writing frame 30 / 1482
# Writing frame 31 / 1482
# Writing frame 32 / 1482
# Writing frame 33 / 1482
# Writing frame 34 / 1482
# Writing frame 35 / 1482
# Writing frame 36 / 1482
# Writing frame 37 / 1482
# Writing frame 38 / 1482
# ...

# %%
# All done!
input_movie.release()
cv2.destroyAllWindows()
